# %% [markdown]
# # Práctica: Análisis formal de un algoritmo elemental
#
# **Análisis de Algoritmos, 2026-1**  **Manuel Soto Romero**  **11 de febrero de 2026**  **Colegio de Ciencia y Tecnología, UACM**

# %% [markdown]
# ## Consideraciones para la entrega
#
# - En parejas.
# - No usar IA; si hay dudas de qué hacer o algún paso, levantar la mano.
# - Es para trabajar en clase. Si no se termina, puede entregarse a más tardar el lunes.
#   Deben tener registrada asistencia; si no se tiene, pueden entregarla el lunes también pero sobre 8.

# %% [markdown]
# ---
#
# ## Suma de múltiplos (Proyecto Euler – Problema 1)
#
# ---

# %% [markdown]
# ## 1. Descripción
#
# En esta práctica se trabajará con un problema clásico del **Proyecto Euler**, cuyo objetivo es resolver un reto matemático mediante programación y posteriormente analizar formalmente su complejidad temporal.
# Los estudiantes deberán implementar una solución en Python, identificar y contar las operaciones elementales del algoritmo propuesto, obtener la función de tiempo (T(n)) en términos del tamaño del problema y, finalmente, demostrar formalmente en qué clase de complejidad (O(·)) se encuentra, justificando la existencia de constantes (k) y (n₀).
#
# El problema es el siguiente (traducción):
#
# > Si listamos todos los números naturales menores que 10 que son múltiplos de 3 o 5, obtenemos 3, 5, 6 y 9. La suma de estos múltiplos es 23.
# >
# > Encuentra la suma de todos los múltiplos de 3 o 5 menores que 1000.

# %% [markdown]
# ## 2. Objetivos
#
# - Implementar una solución correcta en Python para el problema planteado.
# - Modelar formalmente el tiempo de ejecución mediante el conteo de operaciones elementales.
# - Determinar y justificar rigurosamente la clase de complejidad (O(·)) del algoritmo.

# %% [markdown]
# ## 3. Ejercicios
#
# ### Ejercicio 1. Generalización del problema
#
# Antes de programar, responde:
#
# 1. Si en lugar de 1000 usamos un número arbitrario (n), ¿cómo se redefine el problema?
# 2. ¿Qué representa formalmente (n) en términos del tamaño del problema?
#
# **Respuesta:**
#
# -
# -

# %% [markdown]
# ### Ejercicio 2. Implementación en Python
#
# Escribe un programa en Python que:
#
# - Reciba un entero (n).
# - Calcule la suma de todos los números naturales menores que (n) que sean múltiplos de 3 o 5.
# - Imprima el resultado.
#
# Restricciones:
#
# - No usar bibliotecas externas.
# - No usar fórmulas cerradas (por ejemplo, fórmulas de progresiones aritméticas).
# - La solución debe basarse en iteración.

# %%
def suma_multiplos(n):
    # TODO: implementa la solución iterativa
    total = 0
    # for i in range(...):
    #     ...
    return total

n = int(input("n: ") )
print(suma_multiplos(n))

# %% [markdown]
# ### Ejercicio 3. Identificación de operaciones elementales
#
# Sobre tu código:
#
# 1. Define explícitamente qué considerarás como **operaciones elementales** (por ejemplo: asignaciones, comparaciones, suma, módulo, incremento, acceso a variable, etc.).
# 2. Reescribe tu algoritmo en pseudocódigo numerando las líneas.
# 3. Cuenta cuántas veces se ejecuta cada línea en función de (n).
#
# **Operaciones elementales (definición):**
#
# -
#
# **Pseudocódigo numerado:**
#
# 1.
# 2.
# 3.
#
# **Conteo por línea:**
#
# - Línea 1:
# - Línea 2:
# - Línea 3:

# %% [markdown]
# ### Ejercicio 4. Obtención de la función T(n)
#
# 1. Construye la expresión completa de T(n) sumando las contribuciones de cada línea.
# 2. Simplifica la expresión hasta obtener una forma del tipo:
#
#    T(n) = a·n + b
#
# 3. Explica por qué el término dominante es el lineal.
#
# **Respuesta:**
#
# - T(n) =
# - Explicación:

# %% [markdown]
# ### Ejercicio 5. Determinación formal de la clase O(·)
#
# 1. Propón una función candidata g(n).
# 2. Busca constantes k > 0 y n₀ tales que:
#
#    T(n) ≤ k · g(n)  para todo n ≥ n₀
#
# 3. Justifica formalmente tu elección de k y n₀.
# 4. Concluye en qué clase de complejidad se encuentra el algoritmo.
#
# **Respuesta:**
#
# - g(n) =
# - k =
# - n₀ =
# - Conclusión:

# %% [markdown]
# ### Ejercicio 6. Reflexión conceptual
#
# Responde brevemente:
#
# 1. ¿Por qué este algoritmo no puede ser de complejidad constante?
# 2. ¿Podría existir una solución más eficiente en términos asintóticos?
# 3. ¿Qué cambiaría si los múltiplos fueran de 3, 5 y 7?
#
# **Respuesta:**
#
# 1.
# 2.
# 3.
